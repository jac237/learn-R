# %% [markdown]
# # Data Cleaning with Python

# %%
# Imports
import numpy as np
import pandas as pd

# %% [markdown]
# This public data set is taken from [The National Archives](https://webarchive.nationalarchives.gov.uk/20100406121330/http://www.stats4schools.gov.uk/large_datasets/smoking/default.asp) (Part 1 CSV):
#
# > Smoking
# > Who is more likely to smoke? What is the most popular type of tobacco?
# >
# > This data will allow you to look at the smoking habits of over 1000 participants.

# %% [markdown]
# ## Saving file from the web

# %% [markdown]
# Download files with Python: https://stackabuse.com/download-files-with-python/

# %%
import urllib.request

url = "https://webarchive.nationalarchives.gov.uk/20100406121330/http://www.stats4schools.gov.uk/images/smoking_part_1_tcm86-13254.csv"
file_name = "smoking_data.csv"

print('Beginning file download with urllib2...')

urllib.request.urlretrieve(url, file_name)
# Out:
# Beginning file download with urllib2...
# ('smoking_data.csv', <http.client.HTTPMessage at 0x1a1bf90080>)

# %% [markdown]
# ## Error with decoding file

# %%
data_frame = pd.read_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa3 in position 0: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-75-d3bda560fe12> in <module>
# ----> 1 data_frame = pd.read_csv(file_path)
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa3 in position 0: invalid start byte

# %% [markdown]
# ## Reading file as a single string

# %%
with open(file_name, 'rb') as f:
  contents = f.read()

print(contents)
# Out:
# b'Sex,Age,Marital Status,Highest Qualification ,Nationality,Ethnicity,Gross Income,Region,Smoke?,Amount Weekends,Amount Weekdays,Type\r\nMale,38,Divorced,No Qualification,British,White,\xa32600 to less than \xa35200,The North,No,N/A,N/A,N/A\r\nFemale,42,Single,No Qualification,British,White,Less than \xa32600,The North,Yes,12,12,Packets\r\nMale,40,Married,Degree,English,White,\xa328600 to less than \xa336400,The North,No,N/A,N/A,N/A\r\nFemale,40,Married,Degree,English,White,\xa310400 to less than \xa315600,The North,No,N/A,N/A,N/A\r\nFemale,39,Married,GCSE/O Level,British,White,\xa32600 to less than \xa35200,The North,No,N/A,N/A,N/A\r\nFemale,37,Married,GCSE/O Level,British,White,\xa315600 to less than \xa320800,The North,No,N/A,N/A,N/A\r\nMale,53,Married,Degree,British,White,\xa336400 or more,The North,Yes,6,6,Packets\r\nMale,44,Single,Degree,English,White,\xa310400 to less than \xa315600,The North,No,N/A,N/A,N/A\r\nMale,40,Single,GCSE/CSE,English,White,\xa32600 to less than \xa35200,The North,Yes,8,8,Hand-Rolled\r\nFemale,41,Married,No Qualification,English,White,\xa35200 to less than \xa310400,The North,Yes,15,12,Packets\r\nMale,72,Widowed,No Qualification,English,White,\xa310400 to less than \xa315600,The North,No,N/A,N/A,N/A\r\nMale,49,Married,No Qualification,British,White,Refused,The North,No,N/A,N/A,N/A\r\nMale,29,Married,Degree,English,White,\xa336400 or more,The North,No,N/A,N/A,N/A\r\nFemale,79,Widowed,No Qualification,English,White,\xa310400 to less than \xa315600,The North,No,N/A,N/A,N/A\r\nMale,25,Single,Degree,English,White,\xa315600 to less than \xa320800,The North,No,N/A,N/A,N/A\r\nFemale,27,Single,Degree,English,White,\xa315600 to less than \xa320800,The North,No,N/A,N/A,N/A\r\nFemale,30,Single,Degree,English,White,\xa320800 to less than \xa328600,The North,No,N/A,N/A,N/A\r\nMale,47,Divorced,No Qualification,British,White,\xa310400 to less than \xa315600,The North,No,N/A,N/A,N/A\r\nFemale,69,Single,Other/Sub Degree,English,White,\xa32600 to less than \xa35200,The North,No,N/A,N/A,N/A\r\nMale,55,Married,No Qualification,English,White,\xa320800 to less than \xa328600,The North,No,N/A,N/A,N/A\r\nFemale,34,Married,GCSE/CSE,British,White,\xa32600 to less than \xa35200,The North,Yes,6,12,Packets\r\nFemale,36,Married,GCSE/O Level,English,White,\xa35200 to less than \xa310400,The North,Yes,5,2,Packets\r\nFemale,56,Married,No Qualification,English,White,\xa32600 to less than \xa35200,The North,Yes,20,20,Packets\r\nMale,71,Divorced,No Qualification,English,White,Unknown,The North,No,N/A,N/A,N/A\r\nFemale,38,Married,No Qualification,English,White,\xa35200 to less than \xa310400,The North,No,N/A,N/A,N/A\r\nFemale,79,Married,No Qualification,English,White,Less than \xa32600,The North,No,N/A,N/A,N/A\r\nFemale,58,Divorced,No Qualification,English,White,\xa35200 to less than \xa310400,The North,Yes,25,20,Packets\r\nFemale,69,Married,No Qualification,British,White,Less than \xa32600,The North,No,N/A,N/A,N/A\r\nMale,83,Widowed,No Qualification,English,White,\xa32600 to less than \xa35200,The North,No,N/A,N/A,N/A\r\nFemale,73,Widowed,No Qualification,English,White,\xa35200 to less than \xa310400,The North,No,N/A,N/A,N/A\r\nFemale,42,Married,GCSE/O Level,British,White,Refused,The North,Yes,40,15,Packets\r\nFemale,31,Married,GCSE/CSE,English,White,Less than \xa32600,The North,Yes,15,15,Both/Mainly Packets\r\nMale,26,Single,GCSE/CSE,English,White,\xa32600 to less than \xa35200,The North,No,N/A,N/A,N/A\r\nFemale,27,Separated,Degree,English,White,\xa315600 to less than \xa320800,The North,No,N/A,N/A,N/A\r\nFemale,57,Married,Higher/Sub Degree,English,White,\xa310400 to less than \xa315600,The North,No,N/A,N/A,N/A\r\nFemale,30,Married,ONC/BTEC,English,White,\xa32600 to less than \xa35200,The North,No,N/A,N/A,N/A\r\nFemale,22,Single,A Levels,English,White,\xa35200 to less than \xa310400,The North,No,N/A,N/A,N/A\r\nFemale,78,Widowed,No Qualification,English,White,Less than \xa32600,The North,Yes,20,20,Packets\r\nFemale,49,Married,ONC/BT ...

# %% [markdown]
# ## Removing unwanted characters

# %% [markdown]
# Removing unwanted characters: https://stackoverflow.com/questions/42339876/error-unicodedecodeerror-utf-8-codec-cant-decode-byte-0xff-in-position-0-in

# %%
contents = contents.decode('utf-8', 'ignore')
print(contents)
# Out:
# 'Sex,Age,Marital Status,Highest Qualification ,Nationality,Ethnicity,Gross Income,Region,Smoke?,Amount Weekends,Amount Weekdays,Type\r\nMale,38,Divorced,No Qualification,British,White,2600 to less than 5200,The North,No,N/A,N/A,N/A\r\nFemale,42,Single,No Qualification,British,White,Less than 2600,The North,Yes,12,12,Packets\r\nMale,40,Married,Degree,English,White,28600 to less than 36400,The North,No,N/A,N/A,N/A\r\nFemale,40,Married,Degree,English,White,10400 to less than 15600,The North,No,N/A,N/A,N/A\r\nFemale,39,Married,GCSE/O Level,British,White,2600 to less than 5200,The North,No,N/A,N/A,N/A\r\nFemale,37,Married,GCSE/O Level,British,White,15600 to less than 20800,The North,No,N/A,N/A,N/A\r\nMale,53,Married,Degree,British,White,36400 or more,The North,Yes,6,6,Packets\r\nMale,44,Single,Degree,English,White,10400 to less than 15600,The North,No,N/A,N/A,N/A\r\nMale,40,Single,GCSE/CSE,English,White,2600 to less than 5200,The North,Yes,8,8,Hand-Rolled\r\nFemale,41,Married,No Qualification,English,White,5200 to less than 10400,The North,Yes,15,12,Packets\r\nMale,72,Widowed,No Qualification,English,White,10400 to less than 15600,The North,No,N/A,N/A,N/A\r\nMale,49,Married,No Qualification,British,White,Refused,The North,No,N/A,N/A,N/A\r\nMale,29,Married,Degree,English,White,36400 or more,The North,No,N/A,N/A,N/A\r\nFemale,79,Widowed,No Qualification,English,White,10400 to less than 15600,The North,No,N/A,N/A,N/A\r\nMale,25,Single,Degree,English,White,15600 to less than 20800,The North,No,N/A,N/A,N/A\r\nFemale,27,Single,Degree,English,White,15600 to less than 20800,The North,No,N/A,N/A,N/A\r\nFemale,30,Single,Degree,English,White,20800 to less than 28600,The North,No,N/A,N/A,N/A\r\nMale,47,Divorced,No Qualification,British,White,10400 to less than 15600,The North,No,N/A,N/A,N/A\r\nFemale,69,Single,Other/Sub Degree,English,White,2600 to less than 5200,The North,No,N/A,N/A,N/A\r\nMale,55,Married,No Qualification,English,White,20800 to less than 28600,The North,No,N/A,N/A,N/A\r\nFemale,34,Married,GCSE/CSE,British,White,2600 to less than 5200,The North,Yes,6,12,Packets\r\nFemale,36,Married,GCSE/O Level,English,White,5200 to less than 10400,The North,Yes,5,2,Packets\r\nFemale,56,Married,No Qualification,English,White,2600 to less than 5200,The North,Yes,20,20,Packets\r\nMale,71,Divorced,No Qualification,English,White,Unknown,The North,No,N/A,N/A,N/A\r\nFemale,38,Married,No Qualification,English,White,5200 to less than 10400,The North,No,N/A,N/A,N/A\r\nFemale,79,Married,No Qualification,English,White,Less than 2600,The North,No,N/A,N/A,N/A\r\nFemale,58,Divorced,No Qualification,English,White,5200 to less than 10400,The North,Yes,25,20,Packets\r\nFemale,69,Married,No Qualification,British,White,Less than 2600,The North,No,N/A,N/A,N/A\r\nMale,83,Widowed,No Qualification,English,White,2600 to less than 5200,The North,No,N/A,N/A,N/A\r\nFemale,73,Widowed,No Qualification,English,White,5200 to less than 10400,The North,No,N/A,N/A,N/A\r\nFemale,42,Married,GCSE/O Level,British,White,Refused,The North,Yes,40,15,Packets\r\nFemale,31,Married,GCSE/CSE,English,White,Less than 2600,The North,Yes,15,15,Both/Mainly Packets\r\nMale,26,Single,GCSE/CSE,English,White,2600 to less than 5200,The North,No,N/A,N/A,N/A\r\nFemale,27,Separated,Degree,English,White,15600 to less than 20800,The North,No,N/A,N/A,N/A\r\nFemale,57,Married,Higher/Sub Degree,English,White,10400 to less than 15600,The North,No,N/A,N/A,N/A\r\nFemale,30,Married,ONC/BTEC,English,White,2600 to less than 5200,The North,No,N/A,N/A,N/A\r\nFemale,22,Single,A Levels,English,White,5200 to less than 10400,The North,No,N/A,N/A,N/A\r\nFemale,78,Widowed,No Qualification,English,White,Less than 2600,The North,Yes,20,20,Packets\r\nFemale,49,Married,ONC/BTEC,English,Mixed,15600 to less than 20800,The North,No,N/A,N/A,N/A\r\nMale,74,Married,Other/Sub Degree,English,White,15600 to less than 20800,The North,No,N/A,N/A,N/A\r\nMale,85,Widowed,Degree,Scottish,White,20800 to less than 28600,The North,No,N/A,N/A ...

# %% [markdown]
# Notice that the column name "Smoke?" has a question mark which can make things harder when accessing columns in `R`. Let us remove the question mark using the `replace()` function. We can assume that this is the only question mark so we won't be affecting any of the column/row values.

# %%
contents = contents.replace("?", "")
print(contents)
# Out:
# 'Sex,Age,Marital Status,Highest Qualification ,Nationality,Ethnicity,Gross Income,Region,Smoke,Amount Weekends,Amount Weekdays,Type\r\nMale,38,Divorced,No Qualification,British,White,2600 to less than 5200,The North,No,N/A,N/A,N/A\r\nFemale,42,Single,No Qualification,British,White,Less than 2600,The North,Yes,12,12,Packets\r\nMale,40,Married,Degree,English,White,28600 to less than 36400,The North,No,N/A,N/A,N/A\r\nFemale,40,Married,Degree,English,White,10400 to less than 15600,The North,No,N/A,N/A,N/A\r\nFemale,39,Married,GCSE/O Level,British,White,2600 to less than 5200,The North,No,N/A,N/A,N/A\r\nFemale,37,Married,GCSE/O Level,British,White,15600 to less than 20800,The North,No,N/A,N/A,N/A\r\nMale,53,Married,Degree,British,White,36400 or more,The North,Yes,6,6,Packets\r\nMale,44,Single,Degree,English,White,10400 to less than 15600,The North,No,N/A,N/A,N/A\r\nMale,40,Single,GCSE/CSE,English,White,2600 to less than 5200,The North,Yes,8,8,Hand-Rolled\r\nFemale,41,Married,No Qualification,English,White,5200 to less than 10400,The North,Yes,15,12,Packets\r\nMale,72,Widowed,No Qualification,English,White,10400 to less than 15600,The North,No,N/A,N/A,N/A\r\nMale,49,Married,No Qualification,British,White,Refused,The North,No,N/A,N/A,N/A\r\nMale,29,Married,Degree,English,White,36400 or more,The North,No,N/A,N/A,N/A\r\nFemale,79,Widowed,No Qualification,English,White,10400 to less than 15600,The North,No,N/A,N/A,N/A\r\nMale,25,Single,Degree,English,White,15600 to less than 20800,The North,No,N/A,N/A,N/A\r\nFemale,27,Single,Degree,English,White,15600 to less than 20800,The North,No,N/A,N/A,N/A\r\nFemale,30,Single,Degree,English,White,20800 to less than 28600,The North,No,N/A,N/A,N/A\r\nMale,47,Divorced,No Qualification,British,White,10400 to less than 15600,The North,No,N/A,N/A,N/A\r\nFemale,69,Single,Other/Sub Degree,English,White,2600 to less than 5200,The North,No,N/A,N/A,N/A\r\nMale,55,Married,No Qualification,English,White,20800 to less than 28600,The North,No,N/A,N/A,N/A\r\nFemale,34,Married,GCSE/CSE,British,White,2600 to less than 5200,The North,Yes,6,12,Packets\r\nFemale,36,Married,GCSE/O Level,English,White,5200 to less than 10400,The North,Yes,5,2,Packets\r\nFemale,56,Married,No Qualification,English,White,2600 to less than 5200,The North,Yes,20,20,Packets\r\nMale,71,Divorced,No Qualification,English,White,Unknown,The North,No,N/A,N/A,N/A\r\nFemale,38,Married,No Qualification,English,White,5200 to less than 10400,The North,No,N/A,N/A,N/A\r\nFemale,79,Married,No Qualification,English,White,Less than 2600,The North,No,N/A,N/A,N/A\r\nFemale,58,Divorced,No Qualification,English,White,5200 to less than 10400,The North,Yes,25,20,Packets\r\nFemale,69,Married,No Qualification,British,White,Less than 2600,The North,No,N/A,N/A,N/A\r\nMale,83,Widowed,No Qualification,English,White,2600 to less than 5200,The North,No,N/A,N/A,N/A\r\nFemale,73,Widowed,No Qualification,English,White,5200 to less than 10400,The North,No,N/A,N/A,N/A\r\nFemale,42,Married,GCSE/O Level,British,White,Refused,The North,Yes,40,15,Packets\r\nFemale,31,Married,GCSE/CSE,English,White,Less than 2600,The North,Yes,15,15,Both/Mainly Packets\r\nMale,26,Single,GCSE/CSE,English,White,2600 to less than 5200,The North,No,N/A,N/A,N/A\r\nFemale,27,Separated,Degree,English,White,15600 to less than 20800,The North,No,N/A,N/A,N/A\r\nFemale,57,Married,Higher/Sub Degree,English,White,10400 to less than 15600,The North,No,N/A,N/A,N/A\r\nFemale,30,Married,ONC/BTEC,English,White,2600 to less than 5200,The North,No,N/A,N/A,N/A\r\nFemale,22,Single,A Levels,English,White,5200 to less than 10400,The North,No,N/A,N/A,N/A\r\nFemale,78,Widowed,No Qualification,English,White,Less than 2600,The North,Yes,20,20,Packets\r\nFemale,49,Married,ONC/BTEC,English,Mixed,15600 to less than 20800,The North,No,N/A,N/A,N/A\r\nMale,74,Married,Other/Sub Degree,English,White,15600 to less than 20800,The North,No,N/A,N/A,N/A\r\nMale,85,Widowed,Degree,Scottish,White,20800 to less than 28600,The North,No,N/A,N/A, ...

# %% [markdown]
# ## Writing contents to new file

# %% [markdown]
# Reading and Writing Files: https://www.guru99.com/reading-and-writing-files-in-python.html

# %%
file = open("cleaned_data.csv","w+")
file.write(contents)
file.close()

# %% [markdown]
# ## Checking the clean data

# %%
df = pd.read_csv('cleaned_data.csv')
df
# Out:
#          Sex  Age Marital Status Highest Qualification  Nationality Ethnicity  \
# 0       Male   38       Divorced       No Qualification     British     White
# 1     Female   42         Single       No Qualification     British     White
# 2       Male   40        Married                 Degree     English     White
# 3     Female   40        Married                 Degree     English     White
# 4     Female   39        Married           GCSE/O Level     British     White
# 5     Female   37        Married           GCSE/O Level     British     White
# 6       Male   53        Married                 Degree     British     White
# 7       Male   44         Single                 Degree     English     White
# 8       Male   40         Single               GCSE/CSE     English     White
# 9     Female   41        Married       No Qualification     English     White
# 10      Male   72        Widowed       No Qualification     English     White
# 11      Male   49        Married       No Qualification     British     White
# 12      Male   29        Married                 Degree     English     White
# 13    Female   79        Widowed       No Qualification     English     White
# 14      Male   25         Single                 Degree     English     White
# 15    Female   27         Single                 Degree     English     White
# 16    Female   30         Single                 Degree     English     White
# 17      Male   47       Divorced       No Qualification     British     White
# 18    Female   69         Single       Other/Sub Degree     English     White
# 19      Male   55        Married       No Qualification     English     White
# 20    Female   34        Married               GCSE/CSE     British     White
# 21    Female   36        Married           GCSE/O Level     English     White
# 22    Female   56        Married       No Qualification     English     White
# 23      Male   71       Divorced       No Qualification     English     White
# 24    Female   38        Married       No Qualification     English     White
# 25    Female   79        Married       No Qualification     English     White
# 26    Female   58       Divorced       No Qualification     English     White
# 27    Female   69        Married       No Qualification     British     White
# 28      Male   83        Widowed       No Qualification     English     White
# 29    Female   73        Widowed       No Qualification     English     White
# ...      ...  ...            ...                    ...         ...       ...
# 1663    Male   23      Separated           GCSE/O Level    Scottish     White
# 1664    Male   34         Single       No Qualification    Scottish     White
# 1665    Male   24         Single                 Degree    Scottish     White
# 1666    Male   82         Single       Other/Sub Degree    Scottish     White
# 1667    Male   27        Married               A Levels    Scottish     White
# 1668  Female   62       Divorced               GCSE/CSE    Scottish     White
# 1669    Male   39        Married      Higher/Sub Degree     British     White
# 1670    Male   44      Separated       No Qualification    Scottish     White
# 1671  Female   43         Single       No Qualification     British     White
# 1672    Male   31         Single           GCSE/O Level    Scottish     White
# 1673    Male   77       Divorced       Other/Sub Degree     English     White
# 1674  Female   20         Single           GCSE/O Level     English     White
# 1675  Female   81        Widowed       Other/Sub Degree    Scottish     White
# 1676  Female   31         Single           GCSE/O Level    Scottish     White
# 1677  Female   78        Married       Other/Sub Degree    Scottish     White
# 1678    Male   35        Married               A Levels    Scottish     White
# 1679  Female   67        Widowed       No Qualification    Scottish     White
# 1680    Male   65       Divorced       Other/Sub Degree    Scottish     White
# 1681    Male   61        Married      Higher/Sub Degree    Scottish     White
# 1682    Male   24         Single       No Qualification    Scottish     White
# 1683    Male   53         Single       No Qualification    Scottish     White
# 1684  Female   63        Married       No Qualification     British     White
# 1685    Male   35        Married       No Qualification    Scottish     White
# 1686    Male   78        Widowed       No Qualification    Scottish     White
# 1687  Female   31         Single       Other/Sub Degree    Scottish     White
# 1688    Male   22         Single       No Qualification    Scottish     White
# 1689  Female   49       Divorced       Other/Sub Degree     English     White
# 1690    Male   45        Married       Other/Sub Degree    Scottish     White
# 1691  Female   51        Married       No Qualification     English     White
# 1692    Male   31        Married                 Degree    Scottish     White
#
#                   Gross Income     Region Smoke  Amount Weekends  \
# 0       2600 to less than 5200  The North    No              NaN
# 1               Less than 2600  The North   Yes             12.0
# 2     28600 to less than 36400  The North    No              NaN
# 3     10400 to less than 15600  The North    No              NaN
# 4       2600 to less than 5200  The North    No              NaN
# 5     15600 to less than 20800  The North    No              NaN
# 6                36400 or more  The North   Yes              6.0
# 7     10400 to less than 15600  The North    No              NaN
# 8       2600 to less than 5200  The North   Yes              8.0
# 9      5200 to less than 10400  The North   Yes             15.0
# 10    10400 to less than 15600  The North    No              NaN
# 11                     Refused  The North    No              NaN
# 12               36400 or more  The North    No              NaN
# 13    10400 to less than 15600  The North    No              NaN
# 14    15600 to less than 20800  The North    No              NaN
# 15    15600 to less than 20800  The North    No              NaN
# 16    20800 to less than 28600  The North    No              NaN
# 17    10400 to less than 15600  The North    No              NaN
# 18      2600 to less than 5200  The North    No              NaN
# 19    20800 to less than 28600  The North    No              NaN
# 20      2600 to less than 5200  The North   Yes              6.0
# 21     5200 to less than 10400  The North   Yes              5.0
# 22      2600 to less than 5200  The North   Yes             20.0
# 23                     Unknown  The North    No              NaN
# 24     5200 to less than 10400  The North    No              NaN
# 25              Less than 2600  The North    No              NaN
# 26     5200 to less than 10400  The North   Yes             25.0
# 27              Less than 2600  The North    No              NaN
# 28      2600 to less than 5200  The North    No              NaN
# 29     5200 to less than 10400  The North    No              NaN
# ...                        ...        ...   ...              ...
# 1663            Less than 2600   Scotland   Yes              5.0
# 1664  10400 to less than 15600   Scotland   Yes             35.0
# 1665  15600 to less than 20800   Scotland    No              NaN
# 1666   5200 to less than 10400   Scotland    No              NaN
# 1667  15600 to less than 20800   Scotland    No              NaN
# 1668    2600 to less than 5200   Scotland   Yes             18.0
# 1669  20800 to less than 28600   Scotland    No              NaN
# 1670    2600 to less than 5200   Scotland    No              NaN
# 1671  10400 to less than 15600   Scotland   Yes             25.0
# 1672    2600 to less than 5200   Scotland   Yes             20.0
# 1673   5200 to less than 10400   Scotland   Yes             20.0
# 1674   5200 to less than 10400   Scotland    No              NaN
# 1675   5200 to less than 10400   Scotland    No              NaN
# 1676  15600 to less than 20800   Scotland   Yes             20.0
# 1677    2600 to less than 5200   Scotland    No              NaN
# 1678  10400 to less than 15600   Scotland    No              NaN
# 1679            Less than 2600   Scotland    No              NaN
# 1680  10400 to less than 15600   Scotland    No              NaN
# 1681  10400 to less than 15600   Scotland    No              NaN
# 1682            Less than 2600   Scotland   Yes             15.0
# 1683  20800 to less than 28600   Scotland    No              NaN
# 1684                   Refused   Scotland    No              NaN
# 1685  10400 to less than 15600   Scotland   Yes              3.0
# 1686                   Refused   Scotland    No              NaN
# 1687   5200 to less than 10400   Scotland    No              NaN
# 1688    2600 to less than 5200   Scotland    No              NaN
# 1689    2600 to less than 5200   Scotland   Yes             20.0
# 1690   5200 to less than 10400   Scotland    No              NaN
# 1691    2600 to less than 5200   Scotland   Yes             20.0
# 1692  10400 to less than 15600   Scotland    No              NaN
#
#       Amount Weekdays                     Type
# 0                 NaN                      NaN
# 1                12.0                  Packets
# 2                 NaN                      NaN
# 3                 NaN                      NaN
# 4                 NaN                      NaN
# 5                 NaN                      NaN
# 6                 6.0                  Packets
# 7                 NaN                      NaN
# 8                 8.0              Hand-Rolled
# 9                12.0                  Packets
# 10                NaN                      NaN
# 11                NaN                      NaN
# 12                NaN                      NaN
# 13                NaN                      NaN
# 14                NaN                      NaN
# 15                NaN                      NaN
# 16                NaN                      NaN
# 17                NaN                      NaN
# 18                NaN                      NaN
# 19                NaN                      NaN
# 20               12.0                  Packets
# 21                2.0                  Packets
# 22               20.0                  Packets
# 23                NaN                      NaN
# 24                NaN                      NaN
# 25                NaN                      NaN
# 26               20.0                  Packets
# 27                NaN                      NaN
# 28                NaN                      NaN
# 29                NaN                      NaN
# ...               ...                      ...
# 1663              0.0                  Packets
# 1664             18.0  Both/Mainly Hand-Rolled
# 1665              NaN                      NaN
# 1666              NaN                      NaN
# 1667              NaN                      NaN
# 1668             18.0                  Packets
# 1669              NaN                      NaN
# 1670              NaN                      NaN
# 1671             20.0                  Packets
# 1672             15.0      Both/Mainly Packets
# 1673             10.0                  Packets
# 1674              NaN                      NaN
# 1675              NaN                      NaN
# 1676             10.0                  Packets
# 1677              NaN                      NaN
# 1678              NaN                      NaN
# 1679              NaN                      NaN
# 1680              NaN                      NaN
# 1681              NaN                      NaN
# 1682             15.0              Hand-Rolled
# 1683              NaN                      NaN
# 1684              NaN                      NaN
# 1685             12.0                  Packets
# 1686              NaN                      NaN
# 1687              NaN                      NaN
# 1688              NaN                      NaN
# 1689             20.0              Hand-Rolled
# 1690              NaN                      NaN
# 1691             20.0                  Packets
# 1692              NaN                      NaN
#
# [1693 rows x 12 columns]
